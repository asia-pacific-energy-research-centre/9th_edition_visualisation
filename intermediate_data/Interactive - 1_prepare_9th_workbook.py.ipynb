# %% [markdown]
# Connected to env_9th_visualisation (Python 3.11.4)

# %%
#TODO:
#WHY ARE OTHER OIL EMISSIONS IN TRANSPORT SO HIGH. 
# HOW TO CAPTURE GENERATION EMISSIONS AND INCLUDE THEM





# Purpose: This script will create the 9th edition workbook for each economy.
#it is the main script for creating the workbook. it will call functions from workbook_creation_functions.py
#%%
import pickle
import pandas as pd
from datetime import datetime
import os
import shutil
import ast
import workbook_creation_functions
from map_2d_plots import map_9th_data_to_two_dimensional_plots
from map_1d_plots import map_9th_data_to_one_dimensional_plots
from utility_functions import *
def data_checking_warning_or_error(message):
    if STRICT_DATA_CHECKING:
        raise Exception(message)
    else:
        print(message)

#######################################################

# %%
map_data = True
if map_data:
    total_emissions = map_9th_data_to_two_dimensional_plots(FILE_DATE_ID, ECONOMY_ID, EXPECTED_COLS, RAISE_ERROR=False)
# Out:
# The most recent file is: ../input_data/20_USA/merged_file_energy_20_USA_20240405.csv with the date ID 20240405
# The most recent file is: ../input_data/20_USA/capacity_20_USA_20240405.csv with the date ID 20240405
# The most recent file is: ../input_data/20_USA/emissions_20_USA_20240405.csv with the date ID 20240405
# Dataframe for source 'energy' has been modified.
# Dataframe for source 'emissions' has been modified.
# Dataframe for source 'energy' has been modified.
# Dataframe for source 'energy' has been modified.
# Dataframe for source 'energy' has been modified.
# Dataframe for source 'emissions' has been modified.
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\mapping_functions.py:634: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   modified_df = df.append(new_rows, ignore_index=True)
# Dataframe for source 'emissions' has been modified.
# Dataframe for source 'emissions' has been modified.
# there are plotting names in the mappings (e.g. fuels, sectors, capacity, emissions mappings) that are not in new_charts_mapping. These are:
#   {'Transfers', 'Electricity generation', 'International aviation bunkers', 'Ocean', 'Net trade', 'Non-specified_industry', 'Electricity and heat', 'Heat output', 'Liquid and solid renewables', 'Total_fuels', 'Aluminium', 'Power CCS', 'Industry CCS', 'Non-specified_transport', 'Total_sectors', 'Renewables', 'Electricity output', 'Refined products', 'Industry_pos_CCS', 'Transformation', 'Statistical discrepancy', 'International marine bunkers', 'Biojet kerosene', 'Others', 'Freight road', 'Passenger road', 'Modern renewables', 'Non modern renewables', 'Power_pos_CCS', 'Crude & NGL'}
#  This is not an immediate problem, but you may want to remove them from the plotting_df if its getting cluttered.
# there are plotting names in colors_df that are not in plotting_df. These are:
#   {'Crude oil & NGL', 'emissions_intensity', 'Hydrogen_input', 'Refining_output', 'Hydrogen_output', 'Crude oil and NGL', 'renewables_share', 'energy_intensity', 'Refining', 'Total', 'base', 'initial', 'Reference', 'Target', 'renewables_share_in_electricity_generation', 'Power_output', 'Power', 'Storage', 'Power_input', 'rise', 'Refining_input', 'fall'}
# In the column sub1sectors, these variables are missing from the Data sheet ['08_02_interproduct_transfers', '08_03_products_transferred', '09_03_heat_pumps', '09_04_electric_boilers', '09_05_chemical_heat_for_electricity_production', '09_09_petrochemical_industry', '09_11_charcoal_processing', '17_01_transformation_sector', '17_02_industry_sector', '17_03_transport_sector', '17_04_other_sector']
# In the column sub2sectors, these variables are missing from the Data sheet ['09_06_02_liquefaction_regasification_plants', '09_06_04_gastoliquids_plants', '10_01_02_gas_works_plants']
# In the column sub3sectors, these variables are missing from the Data sheet ['15_02_02_01_two_wheeler', '15_02_02_06_two_wheeler_freight', '18_01_02_01_gasturbine', '18_01_02_02_combinedcycle', '18_01_02_03_ccs']
# In the column sub4sectors, these variables are missing from the Data sheet ['15_02_01_06_07_liquified_petroleum_gas', '15_02_02_06_01_diesel_engine', '15_02_02_06_02_gasoline_engine', '15_02_02_06_03_battery_ev', '15_02_02_06_04_compressed_natual_gas', '15_02_02_06_05_plugin_hybrid_ev_gasoline', '15_02_02_06_06_plugin_hybrid_ev_diesel']
# There are plotting_name values for sectors_plotting that may have been lost in the merge. They are probably just missing from the input data. This may or may not be important depending on the rows. These are:     plotting_name                           sectors sub1sectors sub2sectors  \
# 235           NaN    4_international_marine_bunkers         nan         nan
# 236           NaN  5_international_aviation_bunkers         nan         nan
#
#                    sectors_plotting      _merge
# 235    International marine bunkers  right_only
# 236  International aviation bunkers  right_only
# There are sectors_plotting values that have been lost in the merge. These are:     sectors_plotting                         sectors  \
# 18      Power_input  09_total_transformation_sector
# 19      Power_input  09_total_transformation_sector
# 20   Refining_input  09_total_transformation_sector
# 21   Refining_input  09_total_transformation_sector
# 22     Power_output  09_total_transformation_sector
# 23     Power_output  09_total_transformation_sector
# 24  Refining_output  09_total_transformation_sector
# 25  Refining_output  09_total_transformation_sector
#
#                                        sub1sectors      _merge
# 18                          09_04_electric_boilers  right_only
# 19  09_05_chemical_heat_for_electricity_production  right_only
# 20                    09_09_petrochemical_industry  right_only
# 21                       09_11_charcoal_processing  right_only
# 22                          09_04_electric_boilers  right_only
# 23  09_05_chemical_heat_for_electricity_production  right_only
# 24                    09_09_petrochemical_industry  right_only
# 25                       09_11_charcoal_processing  right_only
#
# WARNING: There are plotting_name and aggregate_name combinations that have no data. These are:
#          scenarios economy subtotal_results  source  year  value  \
# 2343830       NaN     NaN              NaN  energy   NaN    NaN
#
#         sectors_plotting fuels_plotting   sheet_name  table_number chart_type  \
# 2343830          Bunkers            Gas  Natural gas           2.0        bar
#
#          chart_title aggregate_name_column plotting_name_column  \
# 2343830  Natural gas        fuels_plotting     sectors_plotting
#
#                        table_id      _merge
# 2343830  energy_Natural gas_2.0  right_only
# In the column sub1sectors, these variables are missing from the Data sheet ['08_02_interproduct_transfers', '08_03_products_transferred', '09_03_heat_pumps', '09_04_electric_boilers', '09_05_chemical_heat_for_electricity_production', '09_09_petrochemical_industry', '09_11_charcoal_processing', '17_01_transformation_sector', '17_02_industry_sector', '17_03_transport_sector', '17_04_other_sector']
# In the column sub2sectors, these variables are missing from the Data sheet ['09_06_02_liquefaction_regasification_plants', '09_06_04_gastoliquids_plants', '10_01_02_gas_works_plants']
# In the column sub3sectors, these variables are missing from the Data sheet ['15_02_02_01_two_wheeler', '15_02_02_06_two_wheeler_freight', '18_01_02_01_gasturbine', '18_01_02_02_combinedcycle', '18_01_02_03_ccs']
# In the column sub4sectors, these variables are missing from the Data sheet ['15_02_01_06_07_liquified_petroleum_gas', '15_02_02_06_01_diesel_engine', '15_02_02_06_02_gasoline_engine', '15_02_02_06_03_battery_ev', '15_02_02_06_04_compressed_natual_gas', '15_02_02_06_05_plugin_hybrid_ev_gasoline', '15_02_02_06_06_plugin_hybrid_ev_diesel']
# There are plotting_name values for sectors_plotting that may have been lost in the merge. They are probably just missing from the input data. This may or may not be important depending on the rows. These are:     plotting_name                           sectors sub1sectors sub2sectors  \
# 235           NaN    4_international_marine_bunkers         nan         nan
# 236           NaN  5_international_aviation_bunkers         nan         nan
#
#                    sectors_plotting      _merge
# 235    International marine bunkers  right_only
# 236  International aviation bunkers  right_only
# There are sectors_plotting values that have been lost in the merge. These are:     sectors_plotting                         sectors  \
# 18      Power_input  09_total_transformation_sector
# 19      Power_input  09_total_transformation_sector
# 20   Refining_input  09_total_transformation_sector
# 21   Refining_input  09_total_transformation_sector
# 22     Power_output  09_total_transformation_sector
# 23     Power_output  09_total_transformation_sector
# 24  Refining_output  09_total_transformation_sector
# 25  Refining_output  09_total_transformation_sector
#
#                                        sub1sectors      _merge
# 18                          09_04_electric_boilers  right_only
# 19  09_05_chemical_heat_for_electricity_production  right_only
# 20                    09_09_petrochemical_industry  right_only
# 21                       09_11_charcoal_processing  right_only
# 22                          09_04_electric_boilers  right_only
# 23  09_05_chemical_heat_for_electricity_production  right_only
# 24                    09_09_petrochemical_industry  right_only
# 25                       09_11_charcoal_processing  right_only
#
# WARNING: There are plotting_name and aggregate_name combinations that have no data. These are:
#          scenarios economy subtotal_layout  source  year  value  \
# 2066454       NaN     NaN             NaN  energy   NaN    NaN
#
#         sectors_plotting fuels_plotting   sheet_name  table_number chart_type  \
# 2066454          Bunkers            Gas  Natural gas           2.0        bar
#
#          chart_title aggregate_name_column plotting_name_column  \
# 2066454  Natural gas        fuels_plotting     sectors_plotting
#
#                        table_id      _merge
# 2066454  energy_Natural gas_2.0  right_only
# Data for 20_USA energy saved.
# In the column sectors, these variables are missing from the Data sheet ['01_production', '02_imports', '03_exports', '04_international_marine_bunkers', '05_international_aviation_bunkers', '06_stock_changes', '07_total_primary_energy_supply', '08_transfers', '09_total_transformation_sector', '10_losses_and_own_use', '11_statistical_discrepancy', '12_total_final_consumption', '13_total_final_energy_consumption', '14_industry_sector', '16_other_sector', '17_nonenergy_use', '18_electricity_output_in_gwh', '19_heat_output_in_pj']
# In the column sub1sectors, these variables are missing from the Data sheet ['08_02_interproduct_transfers', '08_03_products_transferred', '09_01_electricity_plants', '09_02_chp_plants', '09_03_heat_pumps', '09_04_electric_boilers', '09_05_chemical_heat_for_electricity_production', '09_06_gas_processing_plants', '09_07_oil_refineries', '09_08_coal_transformation', '09_09_petrochemical_industry', '09_10_biofuels_processing', '09_11_charcoal_processing', '09_12_nonspecified_transformation', '09_13_hydrogen_transformation', '09_x_heat_plants', '10_01_own_use', '10_02_transmission_and_distribution_losses', '14_01_mining_and_quarrying', '14_02_construction', '14_03_manufacturing', '15_05_pipeline_transport', '15_06_nonspecified_transport', '16_01_buildings', '16_02_agriculture_and_fishing', '16_05_nonspecified_others', '17_01_transformation_sector', '17_02_industry_sector', '17_03_transport_sector', '17_04_other_sector', '18_01_electricity_plants', '18_02_chp_plants', '19_01_chp_plants', '19_02_heat_plants']
# 89  15_02_02_01_two_wheeler_freight    15_02_02_01_06_plugin_hybrid_ev_diesel
# 90  15_02_02_01_two_wheeler_freight    15_02_02_01_07_liquified_petroleum_gas
# 91  15_02_02_01_two_wheeler_freight               15_02_02_01_08_fuel_cell_ev
# 92                              nan                                       nan
# 93                              nan                                       nan
#
#      capacity_plotting      _merge
# 79        CNG vehicles  right_only
# 80       PHEV vehicles  right_only
# 81       PHEV vehicles  right_only
# 82        LPG vehicles  right_only
# 83  Fuel cell vehicles  right_only
# 84        ICE vehicles  right_only
# 85        ICE vehicles  right_only
# 86        BEV vehicles  right_only
# 87        CNG vehicles  right_only
# 88       PHEV vehicles  right_only
# 89       PHEV vehicles  right_only
# 90        LPG vehicles  right_only
# 91  Fuel cell vehicles  right_only
# 92        Nuclear idle  right_only
# 93                Wind  right_only
#
# WARNING: There are plotting_name and aggregate_name combinations that have no data. These are:
#     scenarios economy    source  year  value subtotal_results  \
# 60       NaN     NaN  capacity   NaN    NaN              NaN
# 61       NaN     NaN  capacity   NaN    NaN              NaN
#
#    capacity_plotting       aggregate_name           sheet_name  table_number  \
# 60      Nuclear idle  Generation capacity  Generation capacity           1.0
# 61      Nuclear idle  Generation capacity  Generation capacity           2.0
#
#    chart_type          chart_title aggregate_name_column plotting_name_column  \
# 60       area  Generation capacity        aggregate_name    capacity_plotting
# 61        bar  Generation capacity        aggregate_name    capacity_plotting
#
#                             table_id      _merge
# 60  capacity_Generation capacity_1.0  right_only
# 61  capacity_Generation capacity_2.0  right_only
# In the column sectors, these variables are missing from the Data sheet ['01_production', '02_imports', '03_exports', '04_international_marine_bunkers', '05_international_aviation_bunkers', '06_stock_changes', '07_total_primary_energy_supply', '08_transfers', '09_total_transformation_sector', '10_losses_and_own_use', '11_statistical_discrepancy', '12_total_final_consumption', '13_total_final_energy_consumption', '14_industry_sector', '16_other_sector', '17_nonenergy_use', '18_electricity_output_in_gwh', '19_heat_output_in_pj']
# In the column sub1sectors, these variables are missing from the Data sheet ['08_02_interproduct_transfers', '08_03_products_transferred', '09_01_electricity_plants', '09_02_chp_plants', '09_03_heat_pumps', '09_04_electric_boilers', '09_05_chemical_heat_for_electricity_production', '09_06_gas_processing_plants', '09_07_oil_refineries', '09_08_coal_transformation', '09_09_petrochemical_industry', '09_10_biofuels_processing', '09_11_charcoal_processing', '09_12_nonspecified_transformation', '09_13_hydrogen_transformation', '09_x_heat_plants', '10_01_own_use', '10_02_transmission_and_distribution_losses', '14_01_mining_and_quarrying', '14_02_construction', '14_03_manufacturing', '15_05_pipeline_transport', '15_06_nonspecified_transport', '16_01_buildings', '16_02_agriculture_and_fishing', '16_05_nonspecified_others', '17_01_transformation_sector', '17_02_industry_sector', '17_03_transport_sector', '17_04_other_sector', '18_01_electricity_plants', '18_02_chp_plants', '19_01_chp_plants', '19_02_heat_plants']
# 93                              nan                                       nan
#
#      capacity_plotting      _merge
# 79        CNG vehicles  right_only
# 80       PHEV vehicles  right_only
# 81       PHEV vehicles  right_only
# 82        LPG vehicles  right_only
# 83  Fuel cell vehicles  right_only
# 84        ICE vehicles  right_only
# 85        ICE vehicles  right_only
# 86        BEV vehicles  right_only
# 87        CNG vehicles  right_only
# 88       PHEV vehicles  right_only
# 89       PHEV vehicles  right_only
# 90        LPG vehicles  right_only
# 91  Fuel cell vehicles  right_only
# 92        Nuclear idle  right_only
# 93                Wind  right_only
#
# WARNING: There are plotting_name and aggregate_name combinations that have no data. These are:
#       scenarios economy    source  year  value subtotal_layout  \
# 1170       NaN     NaN  capacity   NaN    NaN             NaN
# 1171       NaN     NaN  capacity   NaN    NaN             NaN
#
#      capacity_plotting       aggregate_name           sheet_name  \
# 1170      Nuclear idle  Generation capacity  Generation capacity
# 1171      Nuclear idle  Generation capacity  Generation capacity
#
#       table_number chart_type          chart_title aggregate_name_column  \
# 1170           1.0       area  Generation capacity        aggregate_name
# 1171           2.0        bar  Generation capacity        aggregate_name
#
#      plotting_name_column                          table_id      _merge
# 1170    capacity_plotting  capacity_Generation capacity_1.0  right_only
# 1171    capacity_plotting  capacity_Generation capacity_2.0  right_only
# Data for 20_USA capacity saved.
# In the column sub1sectors, these variables are missing from the Data sheet ['08_02_interproduct_transfers', '08_03_products_transferred', '09_03_heat_pumps', '09_04_electric_boilers', '09_05_chemical_heat_for_electricity_production', '09_09_petrochemical_industry', '09_11_charcoal_processing', '09_13_hydrogen_transformation', '17_01_transformation_sector', '17_02_industry_sector', '17_03_transport_sector', '17_04_other_sector']
# In the column sub2sectors, these variables are missing from the Data sheet ['09_06_02_liquefaction_regasification_plants', '09_06_04_gastoliquids_plants', '09_13_01_electrolysers', '09_13_02_smr_wo_ccs', '09_13_03_smr_w_ccs', '09_13_04_coal_wo_ccs', '09_13_05_coal_w_ccs', '09_13_06_others', '10_01_02_gas_works_plants']
# In the column sub3sectors, these variables are missing from the Data sheet ['15_02_02_01_two_wheeler', '15_02_02_06_two_wheeler_freight', '18_01_02_01_gasturbine', '18_01_02_02_combinedcycle', '18_01_02_03_ccs']
# In the column sub4sectors, these variables are missing from the Data sheet ['15_02_01_06_07_liquified_petroleum_gas', '15_02_02_06_01_diesel_engine', '15_02_02_06_02_gasoline_engine', '15_02_02_06_03_battery_ev', '15_02_02_06_04_compressed_natual_gas', '15_02_02_06_05_plugin_hybrid_ev_gasoline', '15_02_02_06_06_plugin_hybrid_ev_diesel']
# In the column fuels, these variables are missing from the Data sheet ['19_total', '20_total_renewables', '21_modern_renewables']
# There are plotting_name values for emissions_sectors_plotting that may have been lost in the merge. They are probably just missing from the input data. This may or may not be important depending on the rows. These are:     plotting_name                                           sectors  \
# 268           NaN                    4_international_marine_bunkers
# 269           NaN                  5_international_aviation_bunkers
# 270           NaN              14_industry_sector_emissions_cap_neg
# 271           NaN  09_total_transformation_sector_emissions_cap_neg
# 272           NaN              14_industry_sector_emissions_cap_pos
# 273           NaN  09_total_transformation_sector_emissions_cap_pos
# 274           NaN                 14_industry_sector_emissions_area
# 275           NaN     09_total_transformation_sector_emissions_area
# 276           NaN                09_total_transformation_sector_net
# 277           NaN              14_industry_sector_emissions_cap_neg
# 278           NaN  09_total_transformation_sector_emissions_cap_neg
#
#     sub1sectors sub2sectors      emissions_sectors_plotting      _merge
# 268         nan         nan    International marine bunkers  right_only
# 269         nan         nan  International aviation bunkers  right_only
# 270         nan         nan         Industry carbon capture  right_only
# 271         nan         nan            Power carbon capture  right_only
# 272         nan         nan                Industry_pos_CCS  right_only
# 273         nan         nan                   Power_pos_CCS  right_only
# 274         nan         nan                    Industry CCS  right_only
# 275         nan         nan                       Power CCS  right_only
# 276         nan         nan                   Net emissions  right_only
# 277         nan         nan                   Net emissions  right_only
# 278         nan         nan                   Net emissions  right_only
# There are plotting_name values for emissions_fuels_plotting that may have been lost in the merge. They are probably just missing from the input data. This may or may not be important depending on the rows. These are:     plotting_name                 fuels subfuels emissions_fuels_plotting  \
# 556           NaN              19_total      nan              Total_fuels
# 557           NaN   20_total_renewables      nan         Total renewables
# 558           NaN  21_modern_renewables      nan        Modern renewables
#
#          _merge
# 556  right_only
# 557  right_only
# 558  right_only
# There are sectors_plotting values that have been lost in the merge. These are:     sectors_plotting                         sectors  \
# 16      Power_input  09_total_transformation_sector
# 17      Power_input  09_total_transformation_sector
# 18   Refining_input  09_total_transformation_sector
# 19   Refining_input  09_total_transformation_sector
# 20   Hydrogen_input  09_total_transformation_sector
# 21     Power_output  09_total_transformation_sector
# 22     Power_output  09_total_transformation_sector
# 23  Refining_output  09_total_transformation_sector
# 24  Refining_output  09_total_transformation_sector
# 25  Hydrogen_output  09_total_transformation_sector
#
#                                        sub1sectors      _merge
# 16                          09_04_electric_boilers  right_only
# 17  09_05_chemical_heat_for_electricity_production  right_only
# 18                    09_09_petrochemical_industry  right_only
# 19                       09_11_charcoal_processing  right_only
# 20                   09_13_hydrogen_transformation  right_only
# 21                          09_04_electric_boilers  right_only
# 22  09_05_chemical_heat_for_electricity_production  right_only
# 23                    09_09_petrochemical_industry  right_only
# 24                       09_11_charcoal_processing  right_only
# 25                   09_13_hydrogen_transformation  right_only
# In the column sub1sectors, these variables are missing from the Data sheet ['08_02_interproduct_transfers', '08_03_products_transferred', '09_03_heat_pumps', '09_04_electric_boilers', '09_05_chemical_heat_for_electricity_production', '09_09_petrochemical_industry', '09_11_charcoal_processing', '09_13_hydrogen_transformation', '17_01_transformation_sector', '17_02_industry_sector', '17_03_transport_sector', '17_04_other_sector']
# In the column sub2sectors, these variables are missing from the Data sheet ['09_06_02_liquefaction_regasification_plants', '09_06_04_gastoliquids_plants', '09_13_01_electrolysers', '09_13_02_smr_wo_ccs', '09_13_03_smr_w_ccs', '09_13_04_coal_wo_ccs', '09_13_05_coal_w_ccs', '09_13_06_others', '10_01_02_gas_works_plants']
# In the column sub3sectors, these variables are missing from the Data sheet ['15_02_02_01_two_wheeler', '15_02_02_06_two_wheeler_freight', '18_01_02_01_gasturbine', '18_01_02_02_combinedcycle', '18_01_02_03_ccs']
# In the column sub4sectors, these variables are missing from the Data sheet ['15_02_01_06_07_liquified_petroleum_gas', '15_02_02_06_01_diesel_engine', '15_02_02_06_02_gasoline_engine', '15_02_02_06_03_battery_ev', '15_02_02_06_04_compressed_natual_gas', '15_02_02_06_05_plugin_hybrid_ev_gasoline', '15_02_02_06_06_plugin_hybrid_ev_diesel']
# In the column fuels, these variables are missing from the Data sheet ['19_total', '20_total_renewables', '21_modern_renewables']
# There are plotting_name values for emissions_sectors_plotting that may have been lost in the merge. They are probably just missing from the input data. This may or may not be important depending on the rows. These are:     plotting_name                                           sectors  \
# 269           NaN                    4_international_marine_bunkers
# 270           NaN                  5_international_aviation_bunkers
# 271           NaN              14_industry_sector_emissions_cap_neg
# 272           NaN  09_total_transformation_sector_emissions_cap_neg
# 273           NaN              14_industry_sector_emissions_cap_pos
# 274           NaN  09_total_transformation_sector_emissions_cap_pos
# 275           NaN                 14_industry_sector_emissions_area
# 276           NaN     09_total_transformation_sector_emissions_area
# 277           NaN                09_total_transformation_sector_net
# 278           NaN              14_industry_sector_emissions_cap_neg
# 279           NaN  09_total_transformation_sector_emissions_cap_neg
#
#     sub1sectors sub2sectors      emissions_sectors_plotting      _merge
# 269         nan         nan    International marine bunkers  right_only
# 270         nan         nan  International aviation bunkers  right_only
# 271         nan         nan         Industry carbon capture  right_only
# 272         nan         nan            Power carbon capture  right_only
# 273         nan         nan                Industry_pos_CCS  right_only
# 274         nan         nan                   Power_pos_CCS  right_only
# 275         nan         nan                    Industry CCS  right_only
# 276         nan         nan                       Power CCS  right_only
# 277         nan         nan                   Net emissions  right_only
# 278         nan         nan                   Net emissions  right_only
# 279         nan         nan                   Net emissions  right_only
# There are plotting_name values for emissions_fuels_plotting that may have been lost in the merge. They are probably just missing from the input data. This may or may not be important depending on the rows. These are:     plotting_name                 fuels subfuels emissions_fuels_plotting  \
# 556           NaN              19_total      nan              Total_fuels
# 557           NaN   20_total_renewables      nan         Total renewables
# 558           NaN  21_modern_renewables      nan        Modern renewables
#
#          _merge
# 556  right_only
# 557  right_only
# 558  right_only
# There are sectors_plotting values that have been lost in the merge. These are:     sectors_plotting                         sectors  \
# 16      Power_input  09_total_transformation_sector
# 17      Power_input  09_total_transformation_sector
# 18   Refining_input  09_total_transformation_sector
# 19   Refining_input  09_total_transformation_sector
# 20   Hydrogen_input  09_total_transformation_sector
# 21     Power_output  09_total_transformation_sector
# 22     Power_output  09_total_transformation_sector
# 23  Refining_output  09_total_transformation_sector
# 24  Refining_output  09_total_transformation_sector
# 25  Hydrogen_output  09_total_transformation_sector
#
#                                        sub1sectors      _merge
# 16                          09_04_electric_boilers  right_only
# 17  09_05_chemical_heat_for_electricity_production  right_only
# 18                    09_09_petrochemical_industry  right_only
# 19                       09_11_charcoal_processing  right_only
# 20                   09_13_hydrogen_transformation  right_only
# 21                          09_04_electric_boilers  right_only
# 22  09_05_chemical_heat_for_electricity_production  right_only
# 23                    09_09_petrochemical_industry  right_only
# 24                       09_11_charcoal_processing  right_only
# 25                   09_13_hydrogen_transformation  right_only
# Data for 20_USA emissions saved.
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_2d_plots.py:339: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_emissions = total_emissions.groupby(['scenario', 'year']).sum().reset_index().copy()

# %%
charts_mapping_1d = map_9th_data_to_one_dimensional_plots(ECONOMY_ID, EXPECTED_COLS, total_emissions)
# Out:
# The most recent file is: ../input_data/20_USA/merged_file_energy_20_USA_20240405.csv with the date ID 20240405
# The most recent file is: ../input_data/20_USA/emissions_20_USA_20240405.csv with the date ID 20240405
# The following files were not identified as an energy, capacity or emissions file: ['../input_data/20_USA/capacity_20_USA_20240405.csv']
# The most recent file is: ../input_data/20_USA/merged_file_energy_20_USA_20240405.csv with the date ID 20240405
# The following files were not identified as an energy, capacity or emissions file: ['../input_data/20_USA/capacity_20_USA_20240405.csv', '../input_data/20_USA/emissions_20_USA_20240405.csv']
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:411: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({
# c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\map_1d_plots.py:419: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   kaya_df = kaya_df.append({

# %%
#######################################################
#read in titles, only, from charts mapping for each available economy for the FILE_DATE_ID. e.g. charts_mapping_9th_{economy_x}_{FILE_DATE_ID}.pkl. We will use each of these to create a workbook, for each economy

sources = ['energy', 'emissions', 'capacity']
all_charts_mapping_files_dict = {}
for source in sources:
    charts_mapping_files = [x for x in os.listdir('../intermediate_data/data/') if 'charts_mapping' in x and source in x]
    charts_mapping_files = [x for x in charts_mapping_files if 'pkl' in x]
    charts_mapping_files = [x for x in charts_mapping_files if FILE_DATE_ID in x]
    charts_mapping_files = [x for x in charts_mapping_files if ECONOMY_ID in x]
    if len(charts_mapping_files)>1:
        print(f'We have more than 1 charts mapping input for the source {source}, economy {ECONOMY_ID}: {charts_mapping_files}')
    all_charts_mapping_files_dict[source] = []
    for mappping_file in charts_mapping_files:
        charts_mapping_df = pd.read_pickle(f'../intermediate_data/data/{mappping_file}')
        all_charts_mapping_files_dict[source].append(charts_mapping_df)

if len(charts_mapping_files) == 0:
    raise Exception('No charts mapping files found for FILE_DATE_ID: {}'.format(FILE_DATE_ID))

#add the unique sources form charts_mapping_1d to all_charts_mapping_files_dict
for source in charts_mapping_1d.source.unique():
    all_charts_mapping_files_dict[source] = [charts_mapping_1d[charts_mapping_1d.source==source]]

# %%
############################################
#import master_config xlsx
plotting_specifications = pd.read_excel('../config/master_config.xlsx', sheet_name='plotting_specifications')
plotting_name_to_label = pd.read_excel('../config/master_config.xlsx', sheet_name='plotting_name_to_label')
colours_dict = pd.read_excel('../config/master_config.xlsx', sheet_name='colors')
with open(f'../intermediate_data/config/plotting_names_order_{FILE_DATE_ID}.pkl', 'rb') as handle:
    plotting_names_order = pickle.load(handle)
################################################################################
#FORMAT CONFIGS
################################################################################
#cconvert into dictrionary
if len(plotting_specifications.columns) != 2:
    raise Exception('plotting_specifications must have exactly two columns')
plotting_specifications = plotting_specifications.set_index(plotting_specifications.columns[0]).to_dict()[plotting_specifications.columns[1]]
# Format the bar_years as a list
plotting_specifications['bar_years'] = ast.literal_eval(plotting_specifications['bar_years']) #will be like ['2000', '2010', '2018', '2020', '2030', '2040', '2050'] so format it as a list

plotting_name_to_label_dict = plotting_name_to_label.set_index(plotting_name_to_label.columns[0]).to_dict()[plotting_name_to_label.columns[1]]
colours_dict = colours_dict.set_index(colours_dict.columns[0]).to_dict()[colours_dict.columns[1]]
####################################################################################################################################

# %%
########################################################.
#start process
########################################################.
#PREPARE WORKBOOK
workbook, writer, space_format, percentage_format, header_format, cell_format1, cell_format2 = workbook_creation_functions.prepare_workbook_for_all_charts(ECONOMY_ID, FILE_DATE_ID)

# %%
# Start of the process
for source in all_charts_mapping_files_dict.keys():
    charts_mapping_dfs = all_charts_mapping_files_dict[source]
    for charts_mapping in charts_mapping_dfs:
        workbook, writer = workbook_creation_functions.create_sheets_from_mapping_df(workbook, charts_mapping, total_plotting_names, MIN_YEAR, colours_dict, cell_format1, cell_format2, header_format, plotting_specifications, plotting_names_order, plotting_name_to_label_dict, writer, EXPECTED_COLS, ECONOMY_ID)#workbook, charts_mapping, source, ECONOMY_ID)

#todo add code for macro and renewable share and so on/ 
#save the workbook
writer.close()
# Out:
# WARNING: The following plotting names are not in colours_dict, they will have random colors assigned: ['BEV vehicles', 'CNG vehicles', 'Fuel cell vehicles', 'ICE vehicles', 'LPG vehicles', 'PHEV vehicles']
# WARNING: The following plotting names are not in colours_dict, they will have random colors assigned: ['population', 'real_GDP', 'GDP_per_capita']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\code\1_prepare_9th_workbook.py:10
#       6         workbook, writer = workbook_creation_functions.create_sheets_from_mapping_df(workbook, charts_mapping, total_plotting_names, MIN_YEAR, colours_dict, cell_format1, cell_format2, header_format, plotting_specifications, plotting_names_order, plotting_name_to_label_dict, writer, EXPECTED_COLS, ECONOMY_ID)#workbook, charts_mapping, source, ECONOMY_ID)
#       8 #todo add code for macro and renewable share and so on/
#       9 #save the workbook
# ---> 10 writer.close()
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\pandas\io\excel\_base.py:1480, in ExcelWriter.close(self)
#    1478 def close(self) -> None:
#    1479     """synonym for save, to make it more file-like"""
# -> 1480     self._save()
#    1481     self._handles.close()
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:244, in XlsxWriter._save(self)
#     240 def _save(self) -> None:
#     241     """
#     242     Save workbook to disk.
#     243     """
# --> 244     self.book.close()
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\workbook.py:322, in Workbook.close(self)
#     320 if not self.fileclosed:
#     321     try:
# --> 322         self._store_workbook()
#     323     except IOError as e:
#     324         raise FileCreateError(e)
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\workbook.py:717, in Workbook._store_workbook(self)
#     715 packager._set_tmpdir(self.tmpdir)
#     716 packager._set_in_memory(self.in_memory)
# --> 717 xml_files = packager._create_package()
#     719 # Free up the Packager object.
#     720 packager = None
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\packager.py:140, in Packager._create_package(self)
#     138 self._write_chartsheet_files()
#     139 self._write_workbook_file()
# --> 140 self._write_chart_files()
#     141 self._write_drawing_files()
#     142 self._write_vml_files()
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\packager.py:227, in Packager._write_chart_files(self)
#     219     raise EmptyChartSeries(
#     220         "Chart%d must contain at least one "
#     221         "data series. See chart.add_series()." % index
#     222     )
#     224 chart._set_xml_writer(
#     225     self._filename("xl/charts/chart" + str(index) + ".xml")
#     226 )
# --> 227 chart._assemble_xml_file()
#     228 index += 1
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart.py:661, in Chart._assemble_xml_file(self)
#     658 self._write_protection()
#     660 # Write the c:chart element.
# --> 661 self._write_chart()
#     663 # Write the c:spPr element for the chartarea formatting.
#     664 self._write_sp_pr(self.chartarea)
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart.py:1630, in Chart._write_chart(self)
#    1621         self._write_title_rich(
#    1622             self.title_name,
#    1623             None,
#    (...)
#    1626             self.title_overlay,
#    1627         )
#    1629 # Write the c:plotArea element.
# -> 1630 self._write_plot_area()
#    1632 # Write the c:legend element.
#    1633 self._write_legend()
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart.py:1663, in Chart._write_plot_area(self)
#    1660 self._write_layout(self.plotarea.get("layout"), "plot")
#    1662 # Write  subclass chart type elements for primary and secondary axes.
# -> 1663 self._write_chart_type({"primary_axes": True})
#    1664 self._write_chart_type({"primary_axes": False})
#    1666 # Configure a combined chart if present.
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart_area.py:62, in ChartArea._write_chart_type(self, args)
#      59 def _write_chart_type(self, args):
#      60     # Override the virtual superclass method with a chart specific method.
#      61     # Write the c:areaChart element.
# ---> 62     self._write_area_chart(args)
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart_area.py:93, in ChartArea._write_area_chart(self, args)
#      91 # Write the series elements.
#      92 for data in series:
# ---> 93     self._write_ser(data)
#      95 # Write the c:dropLines element.
#      96 self._write_drop_lines()
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart.py:1792, in Chart._write_ser(self, series)
#    1789 self._write_series_name(series)
#    1791 # Write the c:spPr element.
# -> 1792 self._write_sp_pr(series)
#    1794 # Write the c:marker element.
#    1795 self._write_marker(series["marker"])
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart.py:3218, in Chart._write_sp_pr(self, series)
#    3215         self._write_a_no_fill()
#    3216     else:
#    3217         # Write the a:solidFill element.
# -> 3218         self._write_a_solid_fill(series["fill"])
#    3220 if series.get("pattern"):
#    3221     # Write the a:gradFill element.
#    3222     self._write_a_patt_fill(series["pattern"])
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\chart.py:3281, in Chart._write_a_solid_fill(self, fill)
#    3278 self._xml_start_tag("a:solidFill")
#    3280 if "color" in fill:
# -> 3281     color = get_rgb_color(fill["color"])
#    3282     transparency = fill.get("transparency")
#    3283     # Write the a:srgbClr element.
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\utility.py:443, in get_rgb_color(color)
#     441 def get_rgb_color(color):
#     442     # Convert the user specified color to an RGB color.
# --> 443     rgb_color = xl_color(color)
#     445     # Remove leading FF from RGB color for charts.
#     446     rgb_color = re.sub(r"^FF", "", rgb_color)
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\site-packages\xlsxwriter\utility.py:434, in xl_color(color)
#     431 if color in named_colors:
#     432     color = named_colors[color]
# --> 434 if not re.match("#[0-9a-fA-F]{6}", color):
#     435     warn("Color '%s' isn't a valid Excel color" % color)
#     437 # Convert the RGB color to the Excel ARGB format.
#
# File c:\Users\hyuga.kasai\Documents\Github\9th_Visualization\9th_edition_visualisation\env_9th_visualisation\Lib\re\__init__.py:166, in match(pattern, string, flags)
#     163 def match(pattern, string, flags=0):
#     164     """Try to apply the pattern at the start of the string, returning
#     165     a Match object, or None if no match was found."""
# --> 166     return _compile(pattern, flags).match(string)
#
# TypeError: expected string or bytes-like object, got 'float'
